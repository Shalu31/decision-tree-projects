# %% [markdown]
# <a href="https://colab.research.google.com/github/Shalu31/decision-tree-projects/blob/main/Housingdata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/HousingData.csv')

# %%
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
df.isnull().sum()
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     486 non-null    float64
#  1   ZN       486 non-null    float64
#  2   INDUS    486 non-null    float64
#  3   CHAS     486 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      486 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    486 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  486.000000  486.000000  486.000000  486.000000  506.000000  506.000000
# mean     3.611874   11.211934   11.083992    0.069959    0.554695    6.284634
# std      8.720192   23.388876    6.835896    0.255340    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.081900    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.253715    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.560263   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  486.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.518519    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
df['ZN'] = df['ZN'].replace(0, np.nan)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     486 non-null    float64
#  1   ZN       126 non-null    float64
#  2   INDUS    486 non-null    float64
#  3   CHAS     486 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      486 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    486 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
df.isnull().sum()
# Out:
# CRIM        20
# ZN         380
# INDUS       20
# CHAS        20
# NOX          0
# RM           0
# AGE         20
# DIS          0
# RAD          0
# TAX          0
# PTRATIO      0
# B            0
# LSTAT       20
# MEDV         0
# dtype: int64

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   NaN   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   NaN   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   NaN   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   NaN   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2

# %%
df.isnull().sum()
# Out:
# CRIM        20
# ZN         380
# INDUS       20
# CHAS        20
# NOX          0
# RM           0
# AGE         20
# DIS          0
# RAD          0
# TAX          0
# PTRATIO      0
# B            0
# LSTAT       20
# MEDV         0
# dtype: int64

# %%
df.drop(columns = ['CHAS'], inplace = True)

# %%
df.isnull().sum()
# Out:
# CRIM        20
# ZN         380
# INDUS       20
# NOX          0
# RM           0
# AGE         20
# DIS          0
# RAD          0
# TAX          0
# PTRATIO      0
# B            0
# LSTAT       20
# MEDV         0
# dtype: int64

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS         NOX          RM         AGE  \
# count  486.000000  126.000000  486.000000  506.000000  506.000000  486.000000
# mean     3.611874   43.246032   11.083992    0.554695    6.284634   68.518519
# std      8.720192   26.945927    6.835896    0.115878    0.702617   27.999513
# min      0.006320   12.500000    0.460000    0.385000    3.561000    2.900000
# 25%      0.081900   20.250000    5.190000    0.449000    5.885500   45.175000
# 50%      0.253715   31.500000    9.690000    0.538000    6.208500   76.800000
# 75%      3.560263   70.000000   18.100000    0.624000    6.623500   93.975000
# max     88.976200  100.000000   27.740000    0.871000    8.780000  100.000000
#
#               DIS         RAD         TAX     PTRATIO           B       LSTAT  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  486.000000
# mean     3.795043    9.549407  408.237154   18.455534  356.674032   12.715432
# ...

# %%
df['CRIM'] = df['CRIM'].fillna(df['CRIM'].mean())
df['INDUS'] = df['INDUS'].fillna(df['INDUS'].mean())
df['AGE'] = df['AGE'].fillna(df['AGE'].mean())
df['LSTAT'] = df['LSTAT'].fillna(df['LSTAT'].mean())

# %%
X = df.drop(columns = ['MEDV'])
y = df['MEDV']

# %%
from sklearn.tree import DecisionTreeRegressor
D = DecisionTreeRegressor()
D.fit(X, y)
Y_pred = D.predict(X)
Y_pred
# Out:
# array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#        18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#        15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#        13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
#        21.2, 19.3, 20. , 16.6, 14.4, 19.4, 19.7, 20.5, 25. , 23.4, 18.9,
#        35.4, 24.7, 31.6, 23.3, 19.6, 18.7, 16. , 22.2, 25. , 33. , 23.5,
#        19.4, 22. , 17.4, 20.9, 24.2, 21.7, 22.8, 23.4, 24.1, 21.4, 20. ,
#        20.8, 21.2, 20.3, 28. , 23.9, 24.8, 22.9, 23.9, 26.6, 22.5, 22.2,
#        23.6, 28.7, 22.6, 22. , 22.9, 25. , 20.6, 28.4, 21.4, 38.7, 43.8,
#        33.2, 27.5, 26.5, 18.6, 19.3, 20.1, 19.5, 19.5, 20.4, 19.8, 19.4,
#        21.7, 22.8, 18.8, 18.7, 18.5, 18.3, 21.2, 19.2, 20.4, 19.3, 22. ,
#        20.3, 20.5, 17.3, 18.8, 21.4, 15.7, 16.2, 18. , 14.3, 19.2, 19.6,
#        23. , 18.4, 15.6, 18.1, 17.4, 17.1, 13.3, 17.8, 14. , 14.4, 13.4,
# ...

# %%
from sklearn.metrics import r2_score
r2_score = r2_score(y, Y_pred)
r2_score
# Out:
# 0.9999988294865106

# %%
from sklearn.ensemble import RandomForestRegressor
R = RandomForestRegressor()
R.fit(X, y)
Y_pred = R.predict(X)
Y_pred
# Out:
# array([25.384, 22.021, 34.324, 33.788, 35.345, 27.507, 21.968, 23.665,
#        16.92 , 19.4  , 16.531, 19.663, 21.694, 20.266, 18.761, 20.208,
#        22.573, 17.651, 19.44 , 18.735, 13.933, 19.28 , 15.617, 14.733,
#        15.632, 14.356, 16.976, 14.716, 19.252, 22.261, 13.431, 16.11 ,
#        14.154, 13.486, 13.762, 19.881, 20.537, 21.088, 23.936, 29.529,
#        34.478, 28.281, 24.936, 24.515, 21.536, 19.346, 20.129, 17.579,
#        16.261, 19.566, 19.852, 20.885, 24.931, 22.503, 19.105, 34.969,
#        24.132, 31.492, 23.346, 19.791, 18.937, 17.341, 23.205, 25.204,
#        33.227, 24.151, 19.523, 21.254, 18.252, 20.937, 24.125, 21.602,
#        23.186, 22.867, 24.159, 21.81 , 20.343, 21.102, 21.282, 20.698,
#        27.389, 24.689, 24.293, 23.221, 23.33 , 26.865, 21.772, 22.111,
#        26.101, 29.782, 22.574, 22.012, 22.914, 24.855, 21.003, 27.898,
#        21.804, 41.118, 43.176, 32.85 , 26.448, 26.285, 19.099, 20.009,
# ...

# %%
from sklearn.metrics import r2_score
r2_score = r2_score(y, Y_pred)
r2_score
# Out:
# 0.9780160216873628

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import tree
tree.plot_tree(D)
plt.show()

# %%
print(tree.export_text(D))
# Out:
# |--- feature_4 <= 6.94
# |   |--- feature_11 <= 14.40
# |   |   |--- feature_6 <= 1.34
# |   |   |   |--- feature_10 <= 339.99
# |   |   |   |   |--- value: [27.90]
# |   |   |   |--- feature_10 >  339.99
# |   |   |   |   |--- value: [50.00]
# |   |   |--- feature_6 >  1.34
# |   |   |   |--- feature_4 <= 6.54
# |   |   |   |   |--- feature_4 <= 6.10
# |   |   |   |   |   |--- feature_0 <= 17.79
# |   |   |   |   |   |   |--- feature_11 <= 7.41
# |   |   |   |   |   |   |   |--- feature_8 <= 534.50
# |   |   |   |   |   |   |   |   |--- feature_9 <= 21.50
# |   |   |   |   |   |   |   |   |   |--- feature_9 <= 16.95
# |   |   |   |   |   |   |   |   |   |   |--- value: [24.30]
# |   |   |   |   |   |   |   |   |   |--- feature_9 >  16.95
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 0.57
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [22.80]
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  0.57
# ...
